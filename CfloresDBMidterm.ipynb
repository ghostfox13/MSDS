# %%
#importing libraries that will be used
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
df_2015 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2015.csv')
df_2016 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2016.csv')
df_2017 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2017.csv')
df_2018 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2018.csv')
df_2019 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2019.csv')
df_2020 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2020.csv')
df_2021 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2021.csv')
df_2022 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2022.csv')
# Out:
# /var/folders/b9/hg5029jn5254ytzgt82n21zc0000gn/T/ipykernel_43275/3461958693.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2019 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2019.csv')
# /var/folders/b9/hg5029jn5254ytzgt82n21zc0000gn/T/ipykernel_43275/3461958693.py:6: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2020 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2020.csv')
# /var/folders/b9/hg5029jn5254ytzgt82n21zc0000gn/T/ipykernel_43275/3461958693.py:7: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2021 = pd.read_csv('/Users/carlosflores/Desktop/Python/bostondata/2021.csv')
# /var/folders/b9/hg5029jn5254ytzgt82n21zc0000gn/T/ipykernel_43275/3461958693.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
#concat all the years of the df, 2016-2022, 7 years total 
frames = [df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022]
dfs = pd.concat(frames)

# %%
#linking data frame to SQL server›
engine = create_engine('postgresql://postgres:Luck@localhost:5432/MidTermSDB')

dfs.to_sql(
'Boston Crime Report 2015-2022',
engine,
index=False
)
# Out:
# 77

# %%
dfs.head(10)
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE          OFFENSE_CODE_GROUP  \
# 0      I172040657          2629                  Harassment
# 1      I182061268          3201               Property Lost
# 2      I162013546          3201               Property Lost
# 3      I152051083          3115          Investigate Person
# 4      I152059178          2647                       Other
# 5      I152049897          3201               Property Lost
# 6      I152054279          1106            Confidence Games
# 7      I152051083          3130             Search Warrants
# 8      I152067251          1102                       Fraud
# 9      I152049588           614  Larceny From Motor Vehicle
#
#                      OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0                             HARASSMENT      C11            397      NaN
# 1                        PROPERTY - LOST      NaN                     NaN
# 2                        PROPERTY - LOST       B3            433      NaN
# ...

# %%
dfs.tail(10)
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 73842       232000117           724                NaN
# 73843       222101109           801                NaN
# 73844       222101098          3007                NaN
# 73845       232000032          3831                NaN
# 73846       222101107          3111                NaN
# 73847       232000091          1402                NaN
# 73848       232000002          3831                NaN
# 73849       232000140           619                NaN
# 73850       232000315          3201                NaN
# 73851       232000052          3114                NaN
#
#                          OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 73842                             AUTO THEFT      D14            778        0
# 73843                       ASSAULT - SIMPLE       A1                       0
# 73844                           SUDDEN DEATH      C11                       0
# ...

# %%
dfs.shape
# Out:
# (656904, 17)

# %%
#Creating new column: District name
districts = dfs['DISTRICT'].unique()
dfs['DISTRICT_NAME'] = np.where(dfs['DISTRICT']=='A1', 'Central Boston',
                           np.where(dfs['DISTRICT']=='A7', 'East Boston',
                           np.where(dfs['DISTRICT']=='A15', 'Charlestown', 
                           np.where(dfs['DISTRICT']=='B2', 'Roxbury',
                           np.where(dfs['DISTRICT']=='B3', 'Mattapan',
                           np.where(dfs['DISTRICT']=='C6', 'South Boston',                           
                           np.where(dfs['DISTRICT']=='C11', 'Dorchester',
                           np.where(dfs['DISTRICT']=='D4', 'South End/Kenmore', 
                           np.where(dfs['DISTRICT']=='D14', 'Allston/Brighton',
                           np.where(dfs['DISTRICT']=='E5', 'West Roxbury',                          
                           np.where(dfs['DISTRICT']=='E13', 'Jamaica Plain',                       
                           np.where(dfs['DISTRICT']=='E18', 'Hyde Park', 'Unspecified'))))))))))))

# %%
#Changing month number to month name
month_map = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
}

dfs['MONTH'] = dfs['MONTH'].map(month_map)

# %%
dfs = dfs.drop(['INCIDENT_NUMBER','OFFENSE_CODE','OFFENSE_DESCRIPTION','DISTRICT','REPORTING_AREA','UCR_PART','Location'], axis=1)

# %%
print(dfs.dtypes)
dfs['OCCURRED_ON_DATE'] = pd.to_datetime(dfs['OCCURRED_ON_DATE'])
dfs['MONTH'] = dfs['OCCURRED_ON_DATE'].dt.month_name()
# Out:
# OFFENSE_CODE_GROUP     object
# SHOOTING               object
# OCCURRED_ON_DATE       object
# YEAR                    int64
# MONTH                 float64
# DAY_OF_WEEK            object
# HOUR                    int64
# STREET                 object
# Lat                   float64
# Long                  float64
# DISTRICT_NAME          object
# dtype: object

# %%
#Creating time frames breaking up the 24 hour day in 4 time blocks
dfs['TIME_FRAME'] = np.where((dfs['OCCURRED_ON_DATE'].dt.hour >= 0) & (dfs['OCCURRED_ON_DATE'].dt.hour < 6),
                                 '00:00 - 6:00am',
                        np.where((dfs['OCCURRED_ON_DATE'].dt.hour >= 6) & (dfs['OCCURRED_ON_DATE'].dt.hour < 12),
                                 '6:01am - 12:00',
                        np.where((dfs['OCCURRED_ON_DATE'].dt.hour >= 12) & (dfs['OCCURRED_ON_DATE'].dt.hour < 18),
                                 '12:00 - 18:00',
                        np.where((dfs['OCCURRED_ON_DATE'].dt.hour >= 18) & (dfs['OCCURRED_ON_DATE'].dt.hour < 24),
                                 '18:00 - 00:00', 'unspecified'))))

# %%
#renaming columns
dfs.rename(columns= {'OFFENSE_CODE_GROUP':'OFFENSE', 'OCCURRED_ON_DATE':'DATE_TIME',
'DAY_OF_WEEK':'DAY'}, inplace = True)

# %%
#renaming columns
dfs.rename(columns= {'OFFENSE_CODE_GROUP':'OFFENSE', 'OCCURRED_ON_DATE':'DATE_TIME',
'DAY_OF_WEEK':'DAY'}, inplace = True)

# %%
dfs['OFFENSE'] = dfs['OFFENSE'].fillna('Unspecified')

# %%
dfs.duplicated().sum()
# Out:
# 11437

# %%
dfs['SHOOTING'] = dfs['SHOOTING'].replace('Y',1)

# %%
dfs['SHOOTING'] = dfs['SHOOTING'].fillna(0)

# %%
dfs.isnull().sum()
# Out:
# OFFENSE              0
# SHOOTING             0
# DATE_TIME            0
# YEAR                 0
# MONTH                0
# DAY                  0
# HOUR                 0
# STREET           11888
# Lat              35298
# Long             35298
# DISTRICT_NAME        0
# TIME_FRAME           0
# dtype: int64

# %%
dfs = dfs.dropna()

# %%
#Taking a look at the data after it has been scrubbed 
dfs.head(5)
# Out:
#               OFFENSE  SHOOTING  DATE_TIME  YEAR MONTH     DAY  HOUR  \
# 0          Harassment       0.0 2015-06-15  2015  June  Monday     0
# 2       Property Lost       0.0 2015-06-15  2015  June  Monday     0
# 3  Investigate Person       0.0 2015-06-15  2015  June  Monday     0
# 4               Other       0.0 2015-06-15  2015  June  Monday     0
# 5       Property Lost       0.0 2015-06-15  2015  June  Monday     0
#
#           STREET        Lat       Long DISTRICT_NAME      TIME_FRAME
# 0   MELBOURNE ST  42.291093 -71.065945    Dorchester  00:00 - 6:00am
# 2     NORFOLK ST  42.283634 -71.082813      Mattapan  00:00 - 6:00am
# 3       PARIS ST  42.377023 -71.032247   East Boston  00:00 - 6:00am
# 4  WASHINGTON ST  42.293606 -71.071887    Dorchester  00:00 - 6:00am
# 5  WASHINGTON ST  42.328663 -71.085634       Roxbury  00:00 - 6:00am

# %%
dfs.tail(5)
# Out:
#            OFFENSE  SHOOTING           DATE_TIME  YEAR     MONTH       DAY  \
# 73846  Unspecified       0.0 2022-12-31 23:11:00  2022  December  Saturday
# 73847  Unspecified       0.0 2022-12-31 23:30:00  2022  December  Saturday
# 73848  Unspecified       0.0 2022-12-31 23:37:00  2022  December  Saturday
# 73849  Unspecified       0.0 2022-12-31 23:45:00  2022  December  Saturday
# 73851  Unspecified       0.0 2022-12-31 23:50:00  2022  December  Saturday
#
#        HOUR           STREET        Lat       Long     DISTRICT_NAME  \
# 73846    23      CAUSEWAY ST  42.365375 -71.061542    Central Boston
# 73847    23       CHARLES ST  42.359790 -71.070782    Central Boston
# 73848    23      COLUMBIA RD  42.319593 -71.062607        Dorchester
# 73849    23    WASHINGTON ST  42.349056 -71.150498  Allston/Brighton
# 73851    23  MOUNT VERNON ST  42.357879 -71.069680    Central Boston
#
#           TIME_FRAME
# 73846  18:00 - 00:00
# 73847  18:00 - 00:00
# 73848  18:00 - 00:00
# ...

# %%
dfs.dtypes
# Out:
# OFFENSE                  object
# SHOOTING                float64
# DATE_TIME        datetime64[ns]
# YEAR                      int64
# MONTH                    object
# DAY                      object
# HOUR                      int64
# STREET                   object
# Lat                     float64
# Long                    float64
# DISTRICT_NAME            object
# TIME_FRAME               object
# dtype: object

# %% [markdown]
# Once data is cleaned, breakdown of crime rate trends will be presented, starting with year, month, day, and finally timeblocks of 6 hour windows.

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(10,10))

# Yearly crime trends
year_ct = []
for i in dfs.YEAR.unique():
    year_ct.append(len(dfs[dfs['YEAR']==i]))
sns.pointplot(x=dfs.YEAR.unique(),y=year_ct,color='red', ax=ax1)
ax1.set_xlabel('Year')
ax1.set_ylabel('Crime Count')
ax1.set_title('Yearly Crime Trends 2015-2022')

# Monthly crime trends
month_ct = []
for i in dfs.MONTH.unique():
    month_ct.append(len(dfs[dfs['MONTH']==i]))
sns.pointplot(x=dfs.MONTH.unique(),y=month_ct,color='blue', ax=ax2)
ax2.set_xlabel('Month')
ax2.set_ylabel('Crime Count')
ax2.set_title('Monthly Crime Trends 2015-2022')

# Daily crime trends
day_ct = []
for i in dfs.DAY.unique():
    day_ct.append(len(dfs[dfs['DAY']==i]))
sns.pointplot(x=dfs.DAY.unique(),y=day_ct,color='green', ax=ax3)
ax3.set_xlabel('Day')
ax3.set_ylabel('Crime Count', fontsize=12)
ax3.set_title('Daily Crime Trends 2015-2022')

#hourly crime trends
hour_ct = []
for i in dfs.TIME_FRAME.unique():
    hour_ct.append(len(dfs[dfs['TIME_FRAME']==i]))
sns.pointplot(x=dfs.TIME_FRAME.unique(),y=hour_ct,color='yellow', ax=ax4)
ax4.set_xlabel('Hours')
ax4.set_ylabel('Crime Count')
ax4.set_title('Hourly Crime Trends 2015-2022')

plt.tight_layout()
plt.show()
sns.set(font_scale=0)

# %%
dailyCrime = dfs.set_index('DATE_TIME')
crimes = pd.DataFrame(dailyCrime.resample('D').size())

# %%
fig, ax = plt.subplots(figsize=(17, 10))
ax.plot(crimes[[0]],color="red")
ax.set_title('Day to Day Crime Counts')
ax.set_xlabel("Date")
ax.set_ylabel("Number of Crimes")
plt.show()

# %%
sns.boxplot(data=crimes)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plotting most common incidents
ax, fig = plt.subplots(figsize=(15,7))
sns.countplot(y = dfs['OFFENSE'], order=dfs['OFFENSE'].value_counts()[:10].index)
plt.ylabel('Crime')
plt.xlabel('NO. of Crimes Committed')
plt.title('Most Common Crimes in Boston (2015-2022')
plt.show()
sns.set(font_scale=1)

# %%
ax, fig = plt.subplots(figsize=(15,7))
sns.countplot(y = dfs['OFFENSE'], order=dfs['OFFENSE'].value_counts()[-10:].index)
plt.ylabel('Crime')
plt.xlabel('NO. of Crimes Committed')
plt.title('Least Common Crimes in Boston (2015-2022')
plt.show()
sns.set(font_scale=1)

# %%
ax, fig = plt.subplots(figsize=(15,7))
sns.countplot(y = dfs['DISTRICT_NAME'], palette='viridis')
plt.ylabel('Districts')
plt.xlabel('Crime Activity per District')
plt.title('Incidents per district (2015-2022')
plt.show()
sns.set(font_scale=1)

# %%
import geopandas as gpd
import folium

# %%
bpd = gpd.read_file('/Users/carlosflores/Downloads/Police_Districts.geojson')

# %%
bpd2 = ('/Users/carlosflores/Downloads/Police_Districts.geojson')

# %%
type(bpd)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
bpd.head()
# Out:
#    OBJECTID DISTRICT   ID BPDGIS_GIS  DISTRICT_ DISTRICT__   ShapeSTArea  \
# 0         1      A15  A15          A         15         15  3.798284e+07
# 1         2       A7   A7          A          7         07  1.401151e+08
# 2         3       A1   A1          A          1         01  4.445582e+07
# 3         4       C6   C6          C          6         06  1.236928e+08
# 4         5       D4   D4          D          4         04  7.000553e+07
#
#    ShapeSTLength                                           geometry
# 0   57556.859964  MULTIPOLYGON (((-71.07416 42.39051, -71.07416 ...
# 1  138468.216080  MULTIPOLYGON (((-70.99644 42.39557, -70.99645 ...
# 2   49080.786370  POLYGON ((-71.05200 42.36884, -71.05219 42.368...
# 3   93915.389108  POLYGON ((-71.04406 42.35403, -71.04400 42.354...
# 4   41040.347429  POLYGON ((-71.07416 42.35724, -71.07436 42.357...

# %%
#Creating new column: District name
districts = bpd['DISTRICT'].unique()
bpd['DISTRICT_NAME'] = np.where(bpd['DISTRICT']=='A1', 'Central Boston',
                           np.where(bpd['DISTRICT']=='A7', 'East Boston',
                           np.where(bpd['DISTRICT']=='A15', 'Charlestown', 
                           np.where(bpd['DISTRICT']=='B2', 'Roxbury',
                           np.where(bpd['DISTRICT']=='B3', 'Mattapan',
                           np.where(bpd['DISTRICT']=='C6', 'South Boston',                           
                           np.where(bpd['DISTRICT']=='C11', 'Dorchester',
                           np.where(bpd['DISTRICT']=='D4', 'South End/Kenmore', 
                           np.where(bpd['DISTRICT']=='D14', 'Allston/Brighton',
                           np.where(bpd['DISTRICT']=='E5', 'West Roxbury',                          
                           np.where(bpd['DISTRICT']=='E13', 'Jamaica Plain',                       
                           np.where(bpd['DISTRICT']=='E18', 'Hyde Park', 'Unspecified'))))))))))))

# %%
bpd.head()
# Out:
#    OBJECTID DISTRICT   ID BPDGIS_GIS  DISTRICT_ DISTRICT__   ShapeSTArea  \
# 0         1      A15  A15          A         15         15  3.798284e+07
# 1         2       A7   A7          A          7         07  1.401151e+08
# 2         3       A1   A1          A          1         01  4.445582e+07
# 3         4       C6   C6          C          6         06  1.236928e+08
# 4         5       D4   D4          D          4         04  7.000553e+07
#
#    ShapeSTLength                                           geometry  \
# 0   57556.859964  MULTIPOLYGON (((-71.07416 42.39051, -71.07416 ...
# 1  138468.216080  MULTIPOLYGON (((-70.99644 42.39557, -70.99645 ...
# 2   49080.786370  POLYGON ((-71.05200 42.36884, -71.05219 42.368...
# 3   93915.389108  POLYGON ((-71.04406 42.35403, -71.04400 42.354...
# 4   41040.347429  POLYGON ((-71.07416 42.35724, -71.07436 42.357...
#
#        DISTRICT_NAME
# 0        Charlestown
# 1        East Boston
# 2     Central Boston
# 3       South Boston
# ...

# %%
d = {'DISTRICT NAME': list(bpd['DISTRICT_NAME']), 'geometry':
list(bpd['geometry'])}

gdf = gpd.GeoDataFrame(d, crs="EPSG:3395")
gdf.head()
# Out:
#        DISTRICT NAME                                           geometry
# 0        Charlestown  MULTIPOLYGON (((-71.074 42.391, -71.074 42.391...
# 1        East Boston  MULTIPOLYGON (((-70.996 42.396, -70.996 42.396...
# 2     Central Boston  POLYGON ((-71.052 42.369, -71.052 42.369, -71....
# 3       South Boston  POLYGON ((-71.044 42.354, -71.044 42.354, -71....
# 4  South End/Kenmore  POLYGON ((-71.074 42.357, -71.074 42.357, -71....

# %%
import contextily
ax = bpd.plot(column='DISTRICT_NAME', figsize=(10,10), alpha=0.5, legend=True)
contextily.add_basemap(ax, crs=bpd.crs.to_string())
plt.title('Boston Police Districts')
plt.axis('off')
plt.show()

# %%
dailyCrimes = dfs.set_index('DATE_TIME')

# %%
crimes = pd.DataFrame(dailyCrimes.resample('D').size())

# %%
gun_act = dailyCrimes[dailyCrimes['SHOOTING'] == 1]
dailyGuns = pd.DataFrame(gun_act.resample('M').size())

# %%
fig, ax = plt.subplots(figsize=(14,7))

ax.plot(dailyGuns[[0]], label = 'Daily Gun Activity')
plt.ylabel('NO. of Gun Related Incidents')
plt.xlabel('Date')
plt.show()

# %%
dailyGuns.describe()
# Out:
#                 0
# count   91.000000
# mean    53.593407
# std     28.779228
# min     11.000000
# 25%     30.000000
# 50%     49.000000
# 75%     71.500000
# max    141.000000

# %% [markdown]
# //Conclusion//
#
# Avg crimes day to day are roughly 225. On the extremes end is above 350 and below 100 reports per day.
#
# The most frequent incidents are motor vechical related and larceny. Roxbury and Dorchester are two disricts with the highest crime rates. From the map above there appears to be a correlation between the districts with highest crimes rates and their proximity to each other.
#
# Most crimes occur between 12:00 and 18:00
#
# Crime rates are steady during the week with a spike on Thursdays into friday, making friday the highest occurrence of incidents
#
# Crime rates from 2015 to 2018 have a bit of fluctuation but overall it is fairly consistent. There is a drop off in 2019 into 2020 followed by a consistent level in incidents from 2020 to 2022. Towards the end of 2022 there is a slight increase in activity. This can be due to the political climate during 2020 in the
# US along with the COVID-19 issues between 2020 and 2022, possible even now.
#
# Incidents seem to be higher during warmer months vs colder months. August is the highest and the lowest is Feb.
